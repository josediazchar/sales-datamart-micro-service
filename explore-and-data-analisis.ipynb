# %% [markdown]
# ### Read data and create Dataframes

# %%
import pandas as pd
import pyarrow.parquet as pq
import glob
import os


extracted_folder_path = "./data"
parquet_files = glob.glob(os.path.join(extracted_folder_path, '*.parquet'))


dataframes = [pd.read_parquet(file) for file in parquet_files]
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df.head()
# Out:
#                                              KeySale     KeyDate KeyStore  \
# 0  5540A1C6-1E83-EE11-8115-F4B520236BD7|5640A1C6-...  2023-11-14    1|007
# 1  60E1ED08-2F6C-EE11-A750-DCFE07082371|61E1ED08-...  2023-10-16    1|004
# 2  4C9DF710-0587-EE11-A777-DCFE07082371|4D9DF710-...  2023-11-19    1|004
# 3  F3769ABC-4182-EE11-A76E-DCFE07082371|74071D14-...  2023-11-13    1|004
# 4  2D513DE7-D27C-EE11-A767-DCFE07082371|0D91B68A-...  2023-11-06    1|004
#
#   KeyWarehouse       KeyCustomer KeyProduct KeyEmployee KeyCurrency  \
# 0       1|1008    1|POS|32694425    1|61889       1|417       1|COP
# 1       1|1005    1|POS|25805420    1|42651       1|569       1|COP
# 2       1|1005  1|POS|1045670943    1|42661       1|569       1|COP
# 3       1|1005    1|POS|56090404    1|42666       1|569       1|COP
# 4       1|1005  1|POS|1126245340    1|42678       1|569       1|COP
#
#   KeyDivision       KeyTicket  ... CostAmount DiscAmount  \
# 0           1  1|F01-00322372  ...   12246.09        0.0
# 1           1  1|F02-00561646  ...   14634.00        0.0
# 2           1  1|F02-00564288  ...    1347.99        0.0
# 3           1  1|F02-00563851  ...    9800.00        0.0
# 4           1  1|F02-00563261  ...    4080.00        0.0
#
#                                              Tickets  \
# 0  {'KeySale': '5540A1C6-1E83-EE11-8115-F4B520236...
# 1  {'KeySale': '60E1ED08-2F6C-EE11-A750-DCFE07082...
# 2  {'KeySale': '4C9DF710-0587-EE11-A777-DCFE07082...
# 3  {'KeySale': 'F3769ABC-4182-EE11-A76E-DCFE07082...
# 4  {'KeySale': '2D513DE7-D27C-EE11-A767-DCFE07082...
#
#                                             Products  \
# 0  {'SubCategoryName': 'PLANTAS MEDICINALES      ...
# 1  {'SubCategoryName': 'CORPORAL                 ...
# 2  {'SubCategoryName': 'CORPORAL                 ...
# 3  {'SubCategoryName': 'INSUMOS                  ...
# 4  {'SubCategoryName': 'ESPACIOS                 ...
#
#                                            Customers  \
# 0  {'KeyCustomer': '1|POS|32694425', 'CustomerCod...
# 1  {'KeyCustomer': '1|POS|25805420', 'CustomerCod...
# 2  {'KeyCustomer': '1|POS|1045670943', 'CustomerC...
# 3  {'KeyCustomer': '1|POS|56090404', 'CustomerCod...
# 4  {'KeyCustomer': '1|POS|1126245340', 'CustomerC...
#
#                                            Employees  \
# 0  {'KeyEmployee': '1|417', 'EmployeeCode': '417'...
# 1  {'KeyEmployee': '1|569', 'EmployeeCode': '569'...
# 2  {'KeyEmployee': '1|569', 'EmployeeCode': '569'...
# 3  {'KeyEmployee': '1|569', 'EmployeeCode': '569'...
# 4  {'KeyEmployee': '1|569', 'EmployeeCode': '569'...
#
#                                               Stores  \
# 0  {'KeyStore': '1|007', 'KeyDivision': '1', 'Sto...
# 1  {'KeyStore': '1|004', 'KeyDivision': '1', 'Sto...
# 2  {'KeyStore': '1|004', 'KeyDivision': '1', 'Sto...
# 3  {'KeyStore': '1|004', 'KeyDivision': '1', 'Sto...
# 4  {'KeyStore': '1|004', 'KeyDivision': '1', 'Sto...
#
#                                            Divisions  \
# 0  {'KeyDivision': '1', 'DivisionCode': '1', 'Div...
# 1  {'KeyDivision': '1', 'DivisionCode': '1', 'Div...
# 2  {'KeyDivision': '1', 'DivisionCode': '1', 'Div...
# 3  {'KeyDivision': '1', 'DivisionCode': '1', 'Div...
# 4  {'KeyDivision': '1', 'DivisionCode': '1', 'Div...
#
#                                                 Time  \
# 0  {'KeyDate': 2023-11-14, 'Datetime': 2023-11-14...
# 1  {'KeyDate': 2023-10-16, 'Datetime': 2023-10-16...
# 2  {'KeyDate': 2023-11-19, 'Datetime': 2023-11-19...
# 3  {'KeyDate': 2023-11-13, 'Datetime': 2023-11-13...
# 4  {'KeyDate': 2023-11-06, 'Datetime': 2023-11-06...
#
#                                                Cedis
# 0  {'KeyCedi': '1|1', 'KeyDivision': '1', 'CediCo...
# 1  {'KeyCedi': '1|1', 'KeyDivision': '1', 'CediCo...
# 2  {'KeyCedi': '1|1', 'KeyDivision': '1', 'CediCo...
# 3  {'KeyCedi': '1|1', 'KeyDivision': '1', 'CediCo...
# 4  {'KeyCedi': '1|1', 'KeyDivision': '1', 'CediCo...
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Clean data

# %%
# Check missing data for columns
missing_data = combined_df.isnull().sum()
missing_data
# Out:
# KeySale         0
# KeyDate         0
# KeyStore        0
# KeyWarehouse    0
# KeyCustomer     0
# KeyProduct      0
# KeyEmployee     0
# KeyCurrency     0
# KeyDivision     0
# KeyTicket       0
# KeyCedi         0
# TicketId        0
# Qty             0
# Amount          0
# CostAmount      0
# DiscAmount      0
# Tickets         0
# Products        0
# Customers       0
# Employees       0
# Stores          0
# Divisions       0
# Time            0
# Cedis           0
# dtype: int64

# %%
# check data types
data_types = combined_df.dtypes
data_types
# Out:
# KeySale          object
# KeyDate          object
# KeyStore         object
# KeyWarehouse     object
# KeyCustomer      object
# KeyProduct       object
# KeyEmployee      object
# KeyCurrency      object
# KeyDivision      object
# KeyTicket        object
# KeyCedi          object
# TicketId         object
# Qty             float64
# Amount          float64
# CostAmount      float64
# DiscAmount      float64
# Tickets          object
# Products         object
# Customers        object
# Employees        object
# Stores           object
# Divisions        object
# Time             object
# Cedis            object
# dtype: object

# %%
# remove rows with missing  for key columns
columns_to_check = ['KeyDate', 'KeyEmployee', 'KeyProduct', 'KeyStore', 'Amount']
cleaned_data = combined_df.dropna(subset=columns_to_check)

# %%
# parse data types for keyDate, Amount and Qty
cleaned_data['KeyDate'] = pd.to_datetime(cleaned_data['KeyDate'])
cleaned_data['Amount'] = pd.to_numeric(cleaned_data['Amount'], errors='coerce')
cleaned_data['Qty'] = pd.to_numeric(cleaned_data['Qty'], errors='coerce')

# %%
# Remove any row for no numeric values on the column Amount
cleaned_data = cleaned_data.dropna(subset=['Amount'])

# %%
# Remove any row for no numeric values on the column Qty
cleaned_data = cleaned_data.dropna(subset=['Qty'])

# %%
# parse to str for key columns
cleaned_data['KeyEmployee'] = cleaned_data['KeyEmployee'].astype(str)
cleaned_data['KeyProduct'] = cleaned_data['KeyProduct'].astype(str)
cleaned_data['KeyStore'] = cleaned_data['KeyStore'].astype(str)

# %%
# check changes 
cleaned_data_info = cleaned_data.info()
cleaned_data_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323326 entries, 0 to 323325
# Data columns (total 24 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   KeySale       323326 non-null  object
#  1   KeyDate       323326 non-null  datetime64[ns]
#  2   KeyStore      323326 non-null  object
#  3   KeyWarehouse  323326 non-null  object
#  4   KeyCustomer   323326 non-null  object
#  5   KeyProduct    323326 non-null  object
#  6   KeyEmployee   323326 non-null  object
#  7   KeyCurrency   323326 non-null  object
#  8   KeyDivision   323326 non-null  object
#  9   KeyTicket     323326 non-null  object
#  10  KeyCedi       323326 non-null  object
#  11  TicketId      323326 non-null  object
#  12  Qty           323326 non-null  float64
#  13  Amount        323326 non-null  float64
#  14  CostAmount    323326 non-null  float64
#  15  DiscAmount    323326 non-null  float64
#  16  Tickets       323326 non-null  object
#  17  Products      323326 non-null  object
#  18  Customers     323326 non-null  object
#  19  Employees     323326 non-null  object
#  20  Stores        323326 non-null  object
#  21  Divisions     323326 non-null  object
#  22  Time          323326 non-null  object
#  23  Cedis         323326 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(19)
# memory usage: 59.2+ MB

# %%
missing_data_cleaned = cleaned_data.isnull().sum()
missing_data_cleaned
# Out:
# KeySale         0
# KeyDate         0
# KeyStore        0
# KeyWarehouse    0
# KeyCustomer     0
# KeyProduct      0
# KeyEmployee     0
# KeyCurrency     0
# KeyDivision     0
# KeyTicket       0
# KeyCedi         0
# TicketId        0
# Qty             0
# Amount          0
# CostAmount      0
# DiscAmount      0
# Tickets         0
# Products        0
# Customers       0
# Employees       0
# Stores          0
# Divisions       0
# Time            0
# Cedis           0
# dtype: int64

# %% [markdown]
# #### Sales by employee in date rage analysis

# %%
cleaned_data['KeyDate'] = pd.to_datetime(cleaned_data['KeyDate'])

start_date = '2023-10-01'
end_date = '2023-11-30'

filtered_data = cleaned_data[(cleaned_data['KeyDate'] >= start_date) & (cleaned_data['KeyDate'] <= end_date)]

sales_by_employee = filtered_data.groupby('KeyEmployee')['Amount'].sum().reset_index()

# %%
sales_by_employee.head()
# Out:
#   KeyEmployee       Amount
# 0     1|10250  81621151.73
# 1     1|10436  19746983.41
# 2     1|10519  11448286.02
# 3     1|10575  21913731.90
# 4     1|10580  47565230.27

# %%
combined_df.head().to_csv('data.csv')
